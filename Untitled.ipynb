# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\acer\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\acer\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\acer\anaconda3\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\acer\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2
import matplotlib.pyplot as plt

# Fungsi untuk menampilkan gambar di Jupyter Notebook
def show_image(image):
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()

# Load model deteksi wajah Haar Cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Load gambar
image = cv2.imread('wajah olvi.jpeg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Deteksi wajah
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

# Gambar kotak di sekitar wajah yang terdeteksi
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Tampilkan gambar dengan kotak di sekitar wajah yang terdeteksi
show_image(image)
